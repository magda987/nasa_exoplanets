# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
url = "http://127.0.0.1:8000/plmass?limit=10000"
data = pd.read_json(url)
data
# Out:
#      pl_masse  st_teff
# 0     197.046  5950.00
# 1         NaN  4746.00
# 2         NaN  4746.00
# 3    3000.000      NaN
# 4         NaN  4679.37
# ..        ...      ...
# 995       NaN  6272.00
# 996       NaN  5185.00
# 997       NaN  5212.90
# 998       NaN      NaN
# 999       NaN  5878.00
#
# [1000 rows x 2 columns]

# %%
data = data.dropna()
data.count()
data.describe()
# Out:
#           pl_masse      st_teff
# count   279.000000   279.000000
# mean    449.124068  5530.386774
# std     850.684675   912.760043
# min       0.400000  2960.000000
# 25%      82.157250  5173.000000
# 50%     232.015900  5750.000000
# 75%     507.719425  6112.500000
# max    7838.323460  8980.000000

# %%
x = data.drop(columns = ["pl_masse"]) # x is temp, so drop mass
y = data["pl_masse"]
y
# Out:
# 0      197.04600
# 7      635.66000
# 8      591.16380
# 9      689.69110
# 29       0.55000
#          ...
# 973     28.50000
# 978    386.48128
# 979    180.20961
# 987    172.26386
# 989     10.00000
# Name: pl_masse, Length: 279, dtype: float64

# %%
plt.xlabel("star temperature")
plt.ylabel("planet mass")
plt.scatter(x,y)

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[2960],[5000]])
# Out:
# /Users/magda/Library/Caches/pypoetry/virtualenvs/nasa-exoplanets-vejkTFCy-py3.10/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-153.67961663,  324.73846801])

# %%
plt.plot(x, model.predict(x), color = "red")

# %%
r_sq = model.score(x,y)
r_sq
# Out:
# 0.06331853579665248
